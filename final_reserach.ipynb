# %% [markdown]
# # Inventory strategy

# %% [markdown]
# ### lambda = 0.5  mu = 6.5(8주)

# %%
import pandas as pd
import matplotlib.pyplot as plt

range = [900, 1000, 1100, 1200, 1300, 1400, 1574, 1739, 1900, 2000, 2262, 2434]

inventory_profits = []

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range:
    df_inventory = pd.read_csv(f"Safety-stock_inventory-strategy_0.5_6.5_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    inventory_profit = df_inventory['profit'].iloc[-1]
    inventory_profits.append(inventory_profit)

# Plot 생성
plt.figure(figsize=(10, 6))
plt.plot(range, inventory_profits, label='Inventory-strategy', marker='s', linestyle = '-', color = 'g')

# 그래프 레이블 및 제목 설정
plt.title('Disruption-frequency = 0.5, recovery = 6.5(8weeks)')
plt.xlabel('Disruption Frequency (lambda)')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.xticks(range)
plt.show()

#monte = 1574(SL = 0.85)/2434 (SL = 0.95)

#variability = 1739 (SL = 0.85)/ 2262(SL = 0.95)

# %% [markdown]
# ### lambda = 2  mu = 26(2주)

# %%
import pandas as pd
import matplotlib.pyplot as plt

range = [100, 200, 300, 422, 511, 651, 665, 700, 800, 900, 1000]

inventory_profits = []

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range:
    df_inventory = pd.read_csv(f"Safety-stock_inventory-strategy_2_26_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    inventory_profit = df_inventory['profit'].iloc[-1]
    inventory_profits.append(inventory_profit)

# Plot 생성
plt.figure(figsize=(10, 6))
plt.plot(range, inventory_profits, label='Inventory-strategy', marker='s', linestyle = '-', color = 'g')

# 그래프 레이블 및 제목 설정
plt.title('Disruption-frequency = 2, recovery = 26')
plt.xlabel('Disruption Frequency (lambda)')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.xticks(range)
plt.show()

#monte = 422(SL = 0.85) / 651(SL = 0.95)

#variability = 511 (SL = 0.85) / 665(SL = 0.95)

# %% [markdown]
# ### lambda = 6  mu = 52(1주)

# %%
import pandas as pd
import matplotlib.pyplot as plt

range = [100, 221, 307, 342, 399, 400, 500, 600, 700, 800]

inventory_profits = []

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range:
    df_inventory = pd.read_csv(f"Safety-stock_inventory-strategy_6_52_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    inventory_profit = df_inventory['profit'].iloc[-1]
    inventory_profits.append(inventory_profit)

# Plot 생성
plt.figure(figsize=(10, 6))
plt.plot(range, inventory_profits, label='Inventory-strategy', marker='s', linestyle = '-', color = 'g')

# 그래프 레이블 및 제목 설정
plt.title('Disruption-frequency = 6, recovery = 52(1week)')
plt.xlabel('Disruption Frequency (lambda)')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.xticks(range)
plt.show()

#monte = 221 (SL = 0.85) / 342(SL = 0.95)

#variability = 307 (SL = 0.85) / 399(SL = 0.95)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Dual sourcing

# %% [markdown]
# ### lambda = 0.5  mu = 6.5(8weeks)

# %%
import pandas as pd
import matplotlib.pyplot as plt

range = [200, 300, 400, 500, 600, 700, 807, 880, 1000, 1100, 1200, 1300, 1400, 1500]

dual_profits = []

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range:
    df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_0.5_6.5_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    dual_profit = df_dual['profit'].iloc[-1]
    dual_profits.append(dual_profit)

# Plot 생성
plt.figure(figsize=(10, 6))
plt.plot(range, dual_profits, label='disruption-frequency = 0.5, recovery = 6.5', marker='o', linestyle = '-', color = 'b')

# 그래프 레이블 및 제목 설정
plt.title('Disruption-frequency = 0.5, recovery = 6.5(8 weeks)')
plt.xlabel('Option reservation quantity')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.xticks(range)
plt.show()

#monte = 807

#variability = 880

#강화학습에서 초기값 880, action의 adjustmentfactor 10

# %% [markdown]
# ### lambda = 2  mu = 26(2weeks)

# %%
import pandas as pd
import matplotlib.pyplot as plt

range = [ 200, 300, 400, 500, 600, 700, 800, 831, 950, 1100, 1200]

dual_profits = []

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range:
    df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_2_26_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    dual_profit = df_dual['profit'].iloc[-1]
    dual_profits.append(dual_profit)

# Plot 생성
plt.figure(figsize=(10, 6))
plt.plot(range, dual_profits, label='disruption-frequency = 2, recovery = 26', marker='o', linestyle = '-', color = 'b')

# 그래프 레이블 및 제목 설정
plt.title('Disruption-frequency = 2, recovery = 26')
plt.xlabel('Disruption Frequency (lambda)')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.xticks(range)
plt.show()

#monte = 831

#variability = 950

#강화학습에서 초기값 831, action의 adjustmentfactor 30
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 10
#       8 # Inventory-strategy 데이터 읽기 및 profit 추출
#       9 for freq in range:
# ---> 10     df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_2_26_0.1_{freq}.csv")
#      11     # 마지막 tick에서의 profit 가져오기
#      12     dual_profit = df_dual['profit'].iloc[-1]
#
# ...

# %% [markdown]
# ### lambda = 6 mu = 52(1week)

# %%
import pandas as pd
import matplotlib.pyplot as plt

range = [800, 900, 1000, 1140, 1200, 1300, 1400, 1500, 1651, 1700, 1800, 1900]

dual_profits = []

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range:
    df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_6_52_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    dual_profit = df_dual['profit'].iloc[-1]
    dual_profits.append(dual_profit)

# Plot 생성
plt.figure(figsize=(10, 6))
plt.plot(range, dual_profits, label='disruption-frequency = 2, recovery = 26', marker='o', linestyle = '-', color = 'b')

# 그래프 레이블 및 제목 설정
plt.title('Disruption-frequency = 6, recovery = 52(1week)')
plt.xlabel('Disruption Frequency (lambda)')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.xticks(range)
plt.show()

#monte = 1140

#variability = 1651

#강화학습에서 초기값 1140, action의 adjustmentfactor 30

# %% [markdown]
# ---------------------------------------------------------------------------

# %% [markdown]
# # RL combined Profit Plot

# %%
df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_0.5_6.5_0.1_868.csv")
df_dual
# Out:
#       ticks  inventory-position  ss-position      cost   revenue    profit  \
# 0         0                   0            0    109221      4900   -104321
# 1         1                   0            0    109221     10050    -99171
# 2         2                   0            0    109221     14900    -94321
# 3         3                   0            0    109221     19950    -89271
# 4         4                   0            0    109221     24350    -84871
# ...     ...                 ...          ...       ...       ...       ...
# 5195   5195                   0            0  11681850  24730700  13048850
# 5196   5196                   0            0  11681850  24735850  13054000
# 5197   5197                   0            0  11681850  24740550  13058700
# 5198   5198                   0            0  11681850  24745700  13063850
# 5199   5199                   0            0  11681850  24750250  13068400
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

range = [200, 300, 400, 500, 600, 700, 807, 880, 1000, 1100, 1200, 1300, 1400, 1500]

dual_profits = []

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range:
    df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_0.5_6.5_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    dual_profit = df_dual['profit'].iloc[-1]
    dual_profits.append(dual_profit)

# Plot 생성
plt.figure(figsize=(10, 6))
plt.plot(range, dual_profits, label='disruption-frequency = 0.5, recovery = 6.5', marker='o', linestyle = '-', color = 'b')

# 그래프 레이블 및 제목 설정
plt.title('Disruption-frequency = 0.5, recovery = 6.5(8 weeks)')
plt.xlabel('Option reservation quantity')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.xticks(range)
plt.show()

# %%
import pandas as pd

# CSV 파일 경로 설정
csv_path = r"C:\Users\user\OneDrive\바탕 화면\RL combined math\dual-sourcing\lambda = 0.5, mu = 6.5\Reinforcement_DQN_Dual-sourcing_0.5_6.5.csv"

# 구분자를 자동으로 감지하여 데이터 읽기
df_rl = pd.read_csv(csv_path, sep=None, engine='python')

# 인덱스가 5199일 때의 revenue 값 가져오기
if 5199 in df_rl.index:
    revenue_at_5199 = df_rl.loc[5199, 'revenue']
    print(f"Revenue at index 5199: {revenue_at_5199}")
else:
    print("Index 5199가 존재하지 않습니다.")
# Out:
# Revenue at index 5199: 13380310

# %%
import pandas as pd

# CSV 파일 경로 설정
csv_path = r"C:\Users\user\OneDrive\바탕 화면\RL combined math\dual-sourcing\lambda = 0.5, mu = 6.5\Reinforcement_DQN_Dual-sourcing_0.5_6.5.csv"

# 구분자를 자동으로 감지하여 데이터 읽기
df_rl = pd.read_csv(csv_path, sep=None, engine='python')
df_rl
# Out:
#       ticks  inventory-position  ss-position      cost   revenue  profit  \
# 0         0                   0       112200      4900   -107300       0
# 1         0                   0       115110      9750   -105360       0
# 2         0                   0       117660     14000   -103660       0
# 3         0                   0       120630     18950   -101680       0
# 4         0                   0       120630     23050    -97580       0
# ...     ...                 ...          ...       ...       ...     ...
# 5248      0                   0     11439150  24939500  13500350       0
# 5249      0                   0     11439150  24944650  13505500       0
# 5250      0                   0     11439150  24949800  13510650       0
# 5251      0                   0     11439150  24954950  13515800       0
# 5252      0                   0     11547180  24959650  13412470       0
#
#       shortage-cost-now  shortage-amount  common-demand  disruption  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 범위 설정
range = [200, 300, 400, 500, 600, 700, 807, 880, 1000, 1100, 1200, 1300, 1400, 1500]
rl_index = 7  # RL이 들어갈 위치
range_labels = range[:rl_index] + ["RL"] + range[rl_index:]

dual_profits = []

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range:
    df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_0.5_6.5_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    dual_profit = df_dual['profit'].iloc[-1]
    dual_profits.append(dual_profit)
    print(dual_profit)

# RL 데이터 추가 (revenue at ticks == 5199)
csv_path = r"C:\Users\user\OneDrive\바탕 화면\RL combined math\dual-sourcing\lambda = 0.5, mu = 6.5\Reinforcement_DQN_Dual-sourcing_0.5_6.5.csv"

# 구분자를 자동으로 감지하여 데이터 읽기
df_rl = pd.read_csv(csv_path, sep=None, engine='python')

# 인덱스가 5199일 때의 revenue 값 가져오기
if 5199 in df_rl.index:
    revenue_at_5199 = df_rl.loc[5199, 'revenue']

# RL 값을 dual_profits 리스트에 추가
dual_profits.insert(rl_index, revenue_at_5199)

print(dual_profits)
# Out:
# 12912200
# 12951520
# 12985220
# 13012520
# 13036940
# 13054760
# 13066180
# 13068660
# 13067020
# 13061540
# 13051220
# 13039220
# 13024320
# 13005500
# [np.int64(12912200), np.int64(12951520), np.int64(12985220), np.int64(13012520), np.int64(13036940), np.int64(13054760), np.int64(13066180), np.int64(13380310), np.int64(13068660), np.int64(13067020), np.int64(13061540), np.int64(13051220), np.int64(13039220), np.int64(13024320), np.int64(13005500)]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 범위 설정
range_values = [200, 300, 400, 500, 600, 700, 807, 880, 1000, 1100, 1200, 1300, 1400, 1500]
rl_index = 8  # RL이 들어갈 위치
range_labels = range_values[:rl_index] + ["RL"] + range_values[rl_index:]

# Dual profits를 사전으로 정의
dual_profits = {}

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range_values:
    df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_0.5_6.5_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    dual_profit = df_dual['profit'].iloc[-1]
    dual_profits[str(freq)] = dual_profit  # 범위를 키로, profit을 값으로 저장
    print(f"Profit for {freq}: {dual_profit}")

# RL 데이터 추가 (revenue at ticks == 5199)
csv_path = r"C:\Users\user\OneDrive\바탕 화면\RL combined math\dual-sourcing\lambda = 0.5, mu = 6.5\Reinforcement_DQN_Dual-sourcing_0.5_6.5.csv"

# 구분자를 자동으로 감지하여 데이터 읽기
df_rl = pd.read_csv(csv_path, sep=None, engine='python')

# 인덱스가 5199일 때의 revenue 값 가져오기
if 5199 in df_rl.index:
    revenue_at_5199 = df_rl.loc[5199, 'revenue']

# RL 값을 dual_profits 리스트에 추가
dual_profits['RL'] = revenue_at_5199
print(dual_profits)

key_order = ['200', '300', '400', '500', '600', '700', '807', '880', 'RL', '1000', '1100', '1200', '1300', '1400', '1500']
sorted_dual_profits = dict(sorted(dual_profits.items(), key=lambda k: key_order.index(k[0])))
print(sorted_dual_profits)

plt.figure(figsize=(12, 6))
plt.plot(
    sorted_dual_profits.keys(),  # x축 레이블 (정렬된 키)
    sorted_dual_profits.values(),  # y축 값 (정렬된 profit 값)
    marker='o', linestyle='-', color='b', label='Dual Profits'
)

# 그래프 레이블 및 제목 설정
plt.title('disruption-frquency = 0.5, recovery = 6.5')
plt.xlabel('Option Reservation Quantity')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Profit for 200: 12912200
# Profit for 300: 12951520
# Profit for 400: 12985220
# Profit for 500: 13012520
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#      12 # Inventory-strategy 데이터 읽기 및 profit 추출
#      13 for freq in range_values:
# ---> 14     df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_0.5_6.5_0.1_{freq}.csv")
#      15     # 마지막 tick에서의 profit 가져오기
#      16     dual_profit = df_dual['profit'].iloc[-1]
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 범위 설정
range_values = [800, 900, 1000, 1140, 1200, 1300, 1400, 1500, 1651, 1700, 1800, 1900]

# Dual profits를 사전으로 정의
dual_profits = {}

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range_values:
    df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_6_52_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    dual_profit = df_dual['profit'].iloc[-1]
    dual_profits[str(freq)] = dual_profit  # 범위를 키로, profit을 값으로 저장
    print(f"Profit for {freq}: {dual_profit}")

# RL 데이터 추가 (revenue at ticks == 5199)
csv_path = r"C:\Users\user\OneDrive\바탕 화면\RL combined math\dual-sourcing\lambda = 6, mu = 52\DQN(better)\Reinforcement_DQN_Dual-sourcing_6_52.csv"

# 구분자를 자동으로 감지하여 데이터 읽기
df_rl = pd.read_csv(csv_path, sep=None, engine='python')

# 인덱스가 5199일 때의 revenue 값 가져오기
if 5199 in df_rl.index:
    revenue_at_5199 = df_rl.loc[5199, 'revenue']

# RL 값을 dual_profits 리스트에 추가
dual_profits['RL'] = revenue_at_5199
print(dual_profits)

key_order = ['800', '900', '1000', 'RL', '1140', '1200', '1300', '1400', '1500', '1651', '1700', '1800', '1900']
sorted_dual_profits = dict(sorted(dual_profits.items(), key=lambda k: key_order.index(k[0])))
print(sorted_dual_profits)

plt.figure(figsize=(12, 6))
plt.plot(
    sorted_dual_profits.keys(),  # x축 레이블 (정렬된 키)
    sorted_dual_profits.values(),  # y축 값 (정렬된 profit 값)
    marker='o', linestyle='-', color='b', label='Dual Profits'
)

# 그래프 레이블 및 제목 설정
plt.title('disruption-frqneucy = 6, recovery = 52')
plt.xlabel('Option Reservation Quantity')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Profit for 800: 11891220
# Profit for 900: 11935800
# Profit for 1000: 11956020
# Profit for 1140: 11956740
# Profit for 1200: 11951980
# Profit for 1300: 11941600
# Profit for 1400: 11923240
# Profit for 1500: 11897440
# Profit for 1651: 11855340
# Profit for 1700: 11841620
# Profit for 1800: 11811780
# Profit for 1900: 11781780
# {'800': np.int64(11891220), '900': np.int64(11935800), '1000': np.int64(11956020), '1140': np.int64(11956740), '1200': np.int64(11951980), '1300': np.int64(11941600), '1400': np.int64(11923240), '1500': np.int64(11897440), '1651': np.int64(11855340), '1700': np.int64(11841620), '1800': np.int64(11811780), '1900': np.int64(11781780), 'RL': np.int64(12144290)}
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 범위 설정
range_values = [100, 200, 300, 400, 500, 600, 700, 831, 950, 1100, 1200]

# Dual profits를 사전으로 정의
dual_profits = {}

# Inventory-strategy 데이터 읽기 및 profit 추출
for freq in range_values:
    df_dual = pd.read_csv(f"Option-reservation_Dual-sourcing_2_26_0.1_{freq}.csv")
    # 마지막 tick에서의 profit 가져오기
    dual_profit = df_dual['profit'].iloc[-1]
    dual_profits[str(freq)] = dual_profit  # 범위를 키로, profit을 값으로 저장
    print(f"Profit for {freq}: {dual_profit}")

# RL 데이터 추가 (revenue at ticks == 5199)
csv_path = r"C:\Users\user\OneDrive\바탕 화면\RL combined math\dual-sourcing\lambda = 2, mu = 26\Reinforcement_DQN_Dual-sourcing_2_26.csv"

# 구분자를 자동으로 감지하여 데이터 읽기
df_rl = pd.read_csv(csv_path, sep=None, engine='python')

# 인덱스가 5199일 때의 revenue 값 가져오기
if 5199 in df_rl.index:
    revenue_at_5199 = df_rl.loc[5199, 'revenue']

# RL 값을 dual_profits 리스트에 추가
dual_profits['RL'] = revenue_at_5199
print(dual_profits)

key_order = ['100', '200', '300', '400', '500', '600', '700', 'RL', '831', '950', '1100', '1200']
sorted_dual_profits = dict(sorted(dual_profits.items(), key=lambda k: key_order.index(k[0])))
print(sorted_dual_profits)

plt.figure(figsize=(12, 6))
plt.plot(
    sorted_dual_profits.keys(),  # x축 레이블 (정렬된 키)
    sorted_dual_profits.values(),  # y축 값 (정렬된 profit 값)
    marker='o', linestyle='-', color='b', label='Dual Profits'
)

# 그래프 레이블 및 제목 설정
plt.title('disruption-frqneucy = 2, recovery = 26')
plt.xlabel('Option Reservation Quantity')
plt.ylabel('Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Profit for 100: 12832340
# Profit for 200: 12942020
# Profit for 300: 13033520
# Profit for 400: 13099400
# Profit for 500: 13139840
# Profit for 600: 13166380
# Profit for 700: 13176520
# Profit for 831: 13172820
# Profit for 950: 13155460
# Profit for 1100: 13123420
# Profit for 1200: 13096580
# {'100': np.int64(12832340), '200': np.int64(12942020), '300': np.int64(13033520), '400': np.int64(13099400), '500': np.int64(13139840), '600': np.int64(13166380), '700': np.int64(13176520), '831': np.int64(13172820), '950': np.int64(13155460), '1100': np.int64(13123420), '1200': np.int64(13096580), 'RL': np.int64(13225800)}
# {'100': np.int64(12832340), '200': np.int64(12942020), '300': np.int64(13033520), '400': np.int64(13099400), '500': np.int64(13139840), '600': np.int64(13166380), '700': np.int64(13176520), 'RL': np.int64(13225800), '831': np.int64(13172820), '950': np.int64(13155460), '1100': np.int64(13123420), '1200': np.int64(13096580)}
